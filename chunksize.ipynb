# %%
import pandas as pd
import io
import requests
import numpy as np
import os

import tensorflow.contrib.learn as skflow
import string

from scipy.stats import zscore

from sklearn.model_selection import train_test_split
from sklearn import metrics
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.callbacks import EarlyStopping
from sklearn import preprocessing

#####################################################
#os.system('python 22_05_Transform_columns.py')
#No puedo ponerlo asi por que entonces dice que no esta definido df
#Seguro que hay alguna manera
#####################################################

path = "2july_reduced.csv"
# This file is a CSV, just no CSV extension or headers
df = pd.read_csv(path, header=None, chunksize=200000)

##########################CHUNKSIZE###################################################
chunk_list = [] #append echa chunk df here

#Each chunk is in a df format
for chunk in df:
	#perform filetring
	chunk_filter = chunk_preprocessing(chunk)
	
	
	#once data filtering is done, append the chunk to list
	chunk_list.append(chunk_filter)
	
#concat the list into dataframe
df_concat = pd.df_concat(chunk_list)
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-b3082f10dd85> in <module>
#      25 path = "2july_reduced.csv"
#      26 # This file is a CSV, just no CSV extension or headers
# ---> 27 df = pd.read_csv(path, header=None, chunksize=200000)
#      28
#      29 ##########################CHUNKSIZE###################################################
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'2july_reduced.csv' does not exist: b'2july_reduced.csv'

# %%
pwd
# Out:
# '/Users/beatrizesteban/Google Drive/TFG/TFG'

# %%
import pandas as pd
import io
import requests
import numpy as np
import os

import tensorflow.contrib.learn as skflow
import string

from scipy.stats import zscore

from sklearn.model_selection import train_test_split
from sklearn import metrics
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.callbacks import EarlyStopping
from sklearn import preprocessing

#####################################################
#os.system('python 22_05_Transform_columns.py')
#No puedo ponerlo asi por que entonces dice que no esta definido df
#Seguro que hay alguna manera
#####################################################

path = "july_reduced copia.csv"
# This file is a CSV, just no CSV extension or headers
df = pd.read_csv(path, header=None, chunksize=200000)

##########################CHUNKSIZE###################################################
chunk_list = [] #append echa chunk df here

#Each chunk is in a df format
for chunk in df:
	#perform filetring
	chunk_filter = chunk_preprocessing(chunk)
	
	
	#once data filtering is done, append the chunk to list
	chunk_list.append(chunk_filter)
	
#concat the list into dataframe
df_concat = pd.df_concat(chunk_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-4688f03b76f0> in <module>
#      25 path = "july_reduced copia.csv"
#      26 # This file is a CSV, just no CSV extension or headers
# ---> 27 df = pd.read_csv(path, header=None, chunksize=200000)
#      28
#      29 ##########################CHUNKSIZE###################################################
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'july_reduced copia.csv' does not exist: b'july_reduced copia.csv'

# %%
import pandas as pd
import io
import requests
import numpy as np
import os

import tensorflow.contrib.learn as skflow
import string

from scipy.stats import zscore

from sklearn.model_selection import train_test_split
from sklearn import metrics
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.callbacks import EarlyStopping
from sklearn import preprocessing

#####################################################
#os.system('python 22_05_Transform_columns.py')
#No puedo ponerlo asi por que entonces dice que no esta definido df
#Seguro que hay alguna manera
#####################################################

path = "../july_reduced copia.csv"
# This file is a CSV, just no CSV extension or headers
df = pd.read_csv(path, header=None, chunksize=200000)
for df_chunk in df:
    print(df_chunk.shape)
##########################CHUNKSIZE###################################################
#chunk_list = [] #append echa chunk df here
# Out:
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-490139f4d65c> in <module>
#      26 # This file is a CSV, just no CSV extension or headers
#      27 df = pd.read_csv(path, header=None, chunksize=200000)
# ---> 28 for df_chunk in df:
#      29     print(df_chunk.shape)
#      30 ##########################CHUNKSIZE###################################################
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in __next__(self)
#    1113     def __next__(self):
#    1114         try:
# -> 1115             return self.get_chunk()
#    1116         except StopIteration:
#    1117             self.close()
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#    1171                 raise StopIteration
#    1172             size = min(size, self.nrows - self._currow)
# -> 1173         return self.read(nrows=size)
#    1174
#    1175
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1993     def read(self, nrows=None):
#    1994         try:
# -> 1995             data = self._reader.read(nrows)
#    1996         except StopIteration:
#    1997             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     570
#     571
# --> 572 def is_categorical_dtype(arr_or_dtype):
#     573     """
#     574     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %%
path = "../july_reduced copia.csv"
# This file is a CSV, just no CSV extension or headers
df_not_chunk = pd.read_csv(path, header=None, chunksize=200000)
for df in df_not_chunk:
    print(df.shape)
##########################CHUNKSIZE###################################################
#chunk_list = [] #append echa chunk df here
# Out:
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# (200000, 13)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-8307392a9d4d> in <module>
#       2 # This file is a CSV, just no CSV extension or headers
#       3 df_not_chunk = pd.read_csv(path, header=None, chunksize=200000)
# ----> 4 for df in df_not_chunk:
#       5     print(df.shape)
#       6 ##########################CHUNKSIZE###################################################
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in __next__(self)
#    1113     def __next__(self):
#    1114         try:
# -> 1115             return self.get_chunk()
#    1116         except StopIteration:
#    1117             self.close()
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#    1171                 raise StopIteration
#    1172             size = min(size, self.nrows - self._currow)
# -> 1173         return self.read(nrows=size)
#    1174
#    1175
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1993     def read(self, nrows=None):
#    1994         try:
# -> 1995             data = self._reader.read(nrows)
#    1996         except StopIteration:
#    1997             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     570
#     571
# --> 572 def is_categorical_dtype(arr_or_dtype):
#     573     """
#     574     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %%
print("Read {} rows.".format(len(df)))
# df = df.sample(frac=0.1, replace=False) # Uncomment this line to sample only 10% of the dataset
df.dropna(inplace=True,axis=1) # For now, just drop NA's (rows with missing values)

# The CSV file has no column heads, so add them
df.columns = [
    'time',
    'duration',
    'sip',
    'dip',
    'source_port',
    'dest_port',
    'protocol',
    'flags',
    'forward_status',
    'type_service',
    'pack_exch',
    'bytes',
    'attack_tag'
]

print(df[0:3])
# Out:
# Read 200000 rows.
#                        time  duration             sip           dip  \
# 800000  2016-07-27 13:51:09       0.0  42.219.154.107  143.72.8.137
# 800001  2016-07-27 13:51:09       0.0  42.219.154.107  143.72.8.137
# 800002  2016-07-27 13:51:09       0.0  42.219.154.107  143.72.8.137
#
#         source_port  dest_port protocol   flags  forward_status  type_service  \
# 800000        58717         53      UDP  .A....               0             0
# 800001        59351         53      UDP  .A....               0             0
# 800002        59400         53      UDP  .A....               0             0
#
#         pack_exch  bytes  attack_tag
# 800000          1     57  background
# 800001          1     57  background
# 800002          1     61  background

# %%
df_not_chunk = pd.read_csv(path, header=None, chunksize=200000)
chunk_list = [] #append echa chunk df here

def name_cols(df)
# The CSV file has no column heads, so add them
df.columns = [
    'time',
    'duration',
    'sip',
    'dip',
    'source_port',
    'dest_port',
    'protocol',
    'flags',
    'forward_status',
    'type_service',
    'pack_exch',
    'bytes',
    'attack_tag'
]


for chunk in df_not_chunk:
    print(chunk.shape)
    df = pd.df_concat(chunk)
    #perform filetring
	chunk_filter = name_cols(df)
    #once data filtering is done, append the chunk to list
	#chunk_list.append(chunk_filter)

#concat the list into dataframe
#df = pd.df_concat(chunk_list)
# Out:
#   File "<ipython-input-8-3d641934a02c>", line 4
#     def name_cols(df)
#                      ^
# SyntaxError: invalid syntax

# %%
def name_cols(df)
# The CSV file has no column heads, so add them
df.columns = [
    'time',
    'duration',
    'sip',
    'dip',
    'source_port',
    'dest_port',
    'protocol',
    'flags',
    'forward_status',
    'type_service',
    'pack_exch',
    'bytes',
    'attack_tag'
]


for chunk in df_not_chunk:
    print(chunk.shape)
    df = pd.df_concat(chunk)
    #perform filetring
	chunk_filter = name_cols(df)
    #once data filtering is done, append the chunk to list
	#chunk_list.append(chunk_filter)

#concat the list into dataframe
#df = pd.df_concat(chunk_list)
# Out:
#   File "<ipython-input-9-bd934fffa493>", line 1
#     def name_cols(df)
#                      ^
# SyntaxError: invalid syntax

# %%
def name_cols(df):
# The CSV file has no column heads, so add them
df.columns = [
    'time',
    'duration',
    'sip',
    'dip',
    'source_port',
    'dest_port',
    'protocol',
    'flags',
    'forward_status',
    'type_service',
    'pack_exch',
    'bytes',
    'attack_tag'
]


for chunk in df_not_chunk:
    print(chunk.shape)
    df = pd.df_concat(chunk)
    #perform filetring
	chunk_filter = name_cols(df)
    #once data filtering is done, append the chunk to list
	#chunk_list.append(chunk_filter)

#concat the list into dataframe
#df = pd.df_concat(chunk_list)
# Out:
#   File "<ipython-input-10-6a3fea6d25fc>", line 3
# 19       2502   UDP  .A....   0   0   1    70  background
# 20         53   UDP  .A....   0   0   1    74  background
# 21         53   UDP  .A....   0   0   1    85  background
# 22         53   UDP  .A....   0   0   1    77  background
# 23      41929   UDP  .A....   0   0   1    48  background
# 24       2063   UDP  .A....   0   0   1   480  background
# 25         53   UDP  .A....   0   0   1    56  background
# 26      58000   TCP  .A....   0   8   1    40  background
# 27         80   TCP  ...R..   0  64   1    40  background
# 28         80   TCP  ...R..   0  64   1    40  background
# 29         80   TCP  ...R..   0  64   1    40  background
# ...       ...   ...     ...  ..  ..  ..   ...         ...
# 199970     53   UDP  .A....   0   0   1    79  background
# 199971     53   UDP  .A....   0   0   1    69  background
# 199972     53   UDP  .A....   0   0   1    70  background
# 199973     53   UDP  .A....   0   0   1    70  background
# 199974     53   UDP  .A....   0   0   1    73  background
# 199975     53   UDP  .A....   0   0   1    70  background
# 199976  22571   TCP  ...R..   0  72   1    40  background
# 199977    161   UDP  .A....   0   0   1    74  background
# 199978   1704   TCP  .AP..F   0   0   2   141  background
# 199979   1705   TCP  .AP..F   0   0   2   141  background
# 199980     80   TCP  .AP...   0   0   1    42  background
# 199981  57449   TCP  ...R..   0  40   2    80  background
# 199982  52040   TCP  ...R..   0   0   1    40  background
# 199983  34748   TCP  .A....   0   0   1    52  background
# 199984  50663   TCP  .A....   0   0   1    40  background
# 199985  49909   TCP  .A....   0   0   1    40  background
# 199986  51758   TCP  .A....   0   0   1    40  background
# 199987  44036   TCP  .A....   0   0   1    52  background
# 199988  44037   TCP  .A....   0   0   1    52  background
# 199989  57719   TCP  ...R..   0   0   1    40  background
# 199990  62043   TCP  .A....   0   0   1    52  background
# 199991  62045   TCP  .A....   0   0   1    52  background
# 199992  62046   TCP  .A....   0   0   1    52  background
# 199993  43204   TCP  .AP...   0   0   1    54  background
# 199994  48414   TCP  .AP...   0   0   1    54  background
# 199995  54346   TCP  .AP...   0   0   1    54  background
# 199996  37144   TCP  .AP...   0   0   1    54  background
# 199997   2048  ICMP  .A....   0   0   1    60  background
# 199998  35772   UDP  .A....   0   0   1   141  background
# 199999     53   UDP  .A....   0   0   1    69  background
#
# [200000 rows x 13 columns]
#                          0    1               2               3      4   \
# 200000  2016-07-27 13:45:40  0.0   42.219.157.20    143.72.8.137  54116
# 200001  2016-07-27 13:45:40  0.0   42.219.157.20    143.72.8.137  54141
# 200002  2016-07-27 13:45:40  0.0   42.219.157.20    143.72.8.137  54624
# 200003  2016-07-27 13:45:40  0.0   42.219.157.20    143.72.8.137  54625
# 200004  2016-07-27 13:45:40  0.0   42.219.157.20    143.72.8.137  54891
# 200005  2016-07-27 13:45:40  0.0   42.219.157.20    143.72.8.137  55117
# 200006  2016-07-27 13:45:40  0.0  42.219.157.222    60.24.179.46  39921
# 200007  2016-07-27 13:45:40  0.0   42.219.157.59   150.248.6.234  60594
# 200008  2016-07-27 13:45:40  0.0   42.219.157.60    210.91.66.66     80
# 200009  2016-07-27 13:45:40  0.0   42.219.157.60    210.91.66.66     80
# 399987  2016-07-27 13:47:36  0.0    143.72.8.137  42.219.154.107     53
# 399988  2016-07-27 13:47:36  0.0    143.72.8.137  42.219.154.107     53
# 399989  2016-07-27 13:47:36  0.0    143.72.8.137  42.219.154.107     53
# 399990  2016-07-27 13:47:36  0.0    143.72.8.137  42.219.154.107     53
# 399991  2016-07-27 13:47:36  0.0    143.72.8.137  42.219.154.107     53
# 399992  2016-07-27 13:47:36  0.0    143.72.8.137  42.219.154.107     53
# 399993  2016-07-27 13:47:36  0.0    143.72.8.137  42.219.154.107     53
# 399994  2016-07-27 13:47:36  0.0    143.72.8.137  42.219.154.107     53
# 399995  2016-07-27 13:47:36  0.0    143.72.8.137  42.219.154.107     53
# 399996  2016-07-27 13:47:36  0.0    143.72.8.137  42.219.154.107     53
# 399997  2016-07-27 13:47:36  0.0    143.72.8.137  42.219.154.107     53
# 399998  2016-07-27 13:47:36  0.0    143.72.8.137  42.219.154.107     53
# 399999  2016-07-27 13:47:36  0.0    143.72.8.137  42.219.154.107     53
#
#            5    6       7   8   9   10   11          12
# 200000     53  UDP  .A....   0   0   1   77  background
# 200001     53  UDP  .A....   0   0   1  106  background
# 200002     53  UDP  .A....   0   0   1   77  background
# 200003     53  UDP  .A....   0   0   1   79  background
# 200004     53  UDP  .A....   0   0   1   66  background
# 200005     53  UDP  .A....   0   0   1   71  background
# 200006     53  UDP  .A....   0   0   1   68  background
# 200007   5671  TCP  .AP...   0   0   1  114  background
# 200008  62810  TCP  .A.R..   0   0   1   40  background
# 200009  62811  TCP  .A.R..   0   0   1   40  background
# 200010  62812  TCP  .A.R..   0   0   1   40  background
# 200011  62813  TCP  .A.R..   0   0   1   40  background
# 200012  62814  TCP  .A.R..   0   0   1   40  background
# 200013   2402  TCP  .A....   0   0   1   52  background
# 200014   2453  TCP  .A....   0   0   1   52  background
# 200015   2696  TCP  .A....   0   0   1   52  background
# 200016   3359  TCP  .A....   0   0   1   52  background
# 200017   4185  TCP  .A....   0   0   1   52  background
# 200018     53  UDP  .A....   0   0   1   84  background
# 200019     53  UDP  .A....   0   0   1   84  background
# 200020     53  UDP  .A....   0   0   1   64  background
# 200021     53  UDP  .A....   0   0   1   59  background
# 200022     53  UDP  .A....   0   0   1   84  background
# 200023     53  UDP  .A....   0   0   1   84  background
# 200024     53  UDP  .A....   0   0   1   83  background
# 200025     53  UDP  .A....   0   0   1   71  background
# 200026     53  UDP  .A....   0   0   1   72  background
# 200027     53  UDP  .A....   0   0   1   64  background
# 200028     53  UDP  .A....   0   0   1   73  background
# 200029     53  UDP  .A....   0   0   1   84  background
# ...       ...  ...     ...  ..  ..  ..  ...         ...
# 399970  33505  UDP  .A....   0   0   1   93  background
# 399971  33974  UDP  .A....   0   0   1   88  background
# 399972  34608  UDP  .A....   0   0   1   93  background
# 399973  35098  UDP  .A....   0   0   1   93  background
# 399974  35420  UDP  .A....   0   0   1  100  background
# 399975  35461  UDP  .A....   0   0   1   83  background
# 599998  2016-07-27 13:49:24    3.612    42.219.159.92  150.153.103.136  59425
# 599999  2016-07-27 13:49:24    3.628    218.54.56.170   42.219.158.226  54214
#
#            5    6       7   8   9       10        11          12
# 400000  46483  UDP  .A....   0   0       1       128  background
# 400001  48573  UDP  .A....   0   0       1       126  background
# 400002  48874  UDP  .A....   0   0       1        93  background
# 400003  48949  UDP  .A....   0   0       1       285  background
# 400004  49412  UDP  .A....   0   0       1        83  background
# 400005  51428  UDP  .A....   0   0       1       128  background
# 400006  51834  UDP  .A....   0   0       1       122  background
# 400007  52000  UDP  .A....   0   0       1        93  background
# 400008  52253  UDP  .A....   0   0       1       126  background
# 400009  54421  UDP  .A....   0   0       1       178  background
# 400010  54932  UDP  .A....   0   0       1        93  background
# 400011  55769  UDP  .A....   0   0       1       100  background
# 400012  56077  UDP  .A....   0   0       1        88  background
# 400013  57258  UDP  .A....   0   0       1       105  background
# 400014  57267  UDP  .A....   0   0       1        93  background
# 400015  57584  UDP  .A....   0   0       1       130  background
# 400016  58277  UDP  .A....   0   0       1        93  background
# 400017  58764  UDP  .A....   0   0       1        83  background
# 400018  59035  UDP  .A....   0   0       1       128  background
# 400019  59166  UDP  .A....   0   0       1       105  background
# 400020  59726  UDP  .A....   0   0       1       105  background
# 400021  44584  UDP  .A....   0   0       1       161  background
# 400022  53447  UDP  .A....   0   0       1       140  background
# 400023  56430  UDP  .A....   0   0       1       140  background
# 400024  43279  UDP  .A....   0   0       1        83  background
# 400025  47027  UDP  .A....   0   0       1        83  background
# 400026  54583  UDP  .A....   0   0       1        83  background
# 400027  46851  UDP  .A....   0   0       1       150  background
# 400028  48038  UDP  .A....   0   0       1       142  background
# 400029  59601  UDP  .A....   0   0       1        92  background
# ...       ...  ...     ...  ..  ..     ...       ...         ...
# 599970    445  TCP  ....S.   0   0       2        96  background
# 599971    445  TCP  ....S.   0   0       2        96  background
# 599972    445  TCP  ....S.   0   0       2        96  background
# 599973    445  TCP  ....S.   0   0       2        96  background
# 599974    445  TCP  ....S.   0   0       2        96  background
# 599975     25  TCP  ....S.   0  40       6       360  background
# 599976    445  TCP  ....S.   0   0       2        96  background
# 599977    445  TCP  ....S.   0   0       2        96  background
# 599978    445  TCP  ....S.   0   0       2        96  background
# 599979    445  TCP  ....S.   0   0       2        96  background
# 599980    445  TCP  ....S.   0   0       2        96  background
# 599981  24543  TCP  .APRSF   0   0      10      3344  background
# 599982    445  TCP  ....S.   0   0       2        96  background
# 599983    443  TCP  .APRSF   0   0      12      2861  background
# 599984    445  TCP  ....S.   0   0       2        96  background
# 599985    443  TCP  .AP.SF   0  40      13      3108  background
# 599986    443  TCP  .AP.SF   0  72       9      1170  background
# 599987  62560  TCP  .AP.SF   0   0       4       801  background
# 599988  22479  TCP  .APRSF   0   0      10      3344  background
# 599989    443  TCP  .APRSF   0   0      15      3041  background
# 599990   1054  TCP  .AP...   0   0      63      9474  background
# 599991   8000  TCP  .AP...   0   0      72      3936  background
# 599992  16051  TCP  .AP...   0   2      29     38712  background
# 600011  59135  TCP  .AP.S.   0   0  20   2710  background
# 600012     80  TCP  .AP.SF   0   0   9    911  background
# 600013   3405  TCP  .AP.SF   0   0  20  25511  background
# 600014  58819  UDP  .A....   0   0   2    219  background
# 600015     53  UDP  .A....   0   0   2    138  background
# 600016  22001  TCP  .AP...   0   0   6    336  background
# 600017  22001  TCP  .AP...   0   0   6    336  background
# 600018      1  TCP  ....S.   0   0   5    300  background
# 600019  22001  TCP  .AP...   0   0   6    336  background
# 600020    443  TCP  .APRS.   0   0  17   3342  background
# 600021  35979  TCP  .APRSF   0   0  17   9256  background
# 600022  16403  UDP  .A....   0  40   5    220  background
# 600023  16386  UDP  .A....   0   0   5    220  background
# 600024  23930  TCP  .APRSF   0   0  10   3344  background
# 600025    443  TCP  .APRSF   0   0  14   2973  background
# 600026    443  TCP  .APRS.   0   0  17   3328  background
# 600027  35980  TCP  .APRSF   0   0  17   9097  background
# 600028     80  TCP  .AP.SF   0   0  12   1124  background
# 600029    443  TCP  .APRS.   0   0  18   3388  background
# ...       ...  ...     ...  ..  ..  ..    ...         ...
# 799970     53  UDP  .A....   0   0   1     77  background
# 799971     53  UDP  .A....   0   0   1     67  background
# 799972     53  UDP  .A....   0   0   1     77  background
# 799973     53  UDP  .A....   0   0   1     77  background
# 799974     53  UDP  .A....   0   0   1     67  background
# 799975     53  UDP  .A....   0   0   1     61  background
# 799976     53  UDP  .A....   0   0   1     61  background
# 799977     53  UDP  .A....   0   0   1     77  background
# 799978     53  UDP  .A....   0   0   1     61  background
# 799979     53  UDP  .A....   0   0   1     55  background
# 799980     53  UDP  .A....   0   0   1     55  background
# 799981     53  UDP  .A....   0   0   1     55  background
# 799982     53  UDP  .A....   0   0   1     73  background
# 799983     53  UDP  .A....   0   0   1     61  background
# 799984     53  UDP  .A....   0   0   1     61  background
# 799985     53  UDP  .A....   0   0   1     70  background
# 799986     53  UDP  .A....   0   0   1     77  background
# 799987     53  UDP  .A....   0   0   1     61  background
# 799988     53  UDP  .A....   0   0   1     61  background
# 799989     53  UDP  .A....   0   0   1     67  background
# 799990     53  UDP  .A....   0   0   1     55  background
# 799991     53  UDP  .A....   0   0   1     57  background
# 799992     53  UDP  .A....   0   0   1     55  background
# 799993     53  UDP  .A....   0   0   1     61  background
# 799994     53  UDP  .A....   0   0   1     72  background
# 799995     53  UDP  .A....   0   0   1     61  background
# 799996     53  UDP  .A....   0   0   1     57  background
# 799997     53  UDP  .A....   0   0   1     67  background
# 799998     53  UDP  .A....   0   0   1     57  background
# 799999     53  UDP  .A....   0   0   1     61  background
#
# [200000 rows x 13 columns]
#                          0       1                2                3      4   \
# 800000  2016-07-27 13:51:09   0.000   42.219.154.107     143.72.8.137  58717
# 800001  2016-07-27 13:51:09   0.000   42.219.154.107     143.72.8.137  59351
# 800002  2016-07-27 13:51:09   0.000   42.219.154.107     143.72.8.137  59400
# 800003  2016-07-27 13:51:09   0.000   42.219.154.108     143.72.8.137  51449
# 3199973   8000  TCP  .AP...   0   0   1     84  background
# 3199974   8000  TCP  .AP...   0   0   1     84  background
# 3199975   8000  TCP  .AP...   0   0   1     84  background
# 3199976   8000  TCP  .AP...   0   0   1     84  background
# 3199977   8000  TCP  .AP...   0   0   1     84  background
# 3199978   8000  TCP  .AP...   0   0   1     84  background
# 3199979   8000  TCP  .AP...   0   0   1     84  background
# 3199980   8000  TCP  .AP...   0   0   1     84  background
# 3199981   8000  TCP  .AP...   0   0   1     84  background
# 3199982     53  UDP  .A....   0   0   1     89  background
# 3199983     53  UDP  .A....   0   0   1     68  background
# 3199984     53  UDP  .A....   0   0   1     89  background
# 3199985     53  UDP  .A....   0  72   1     76  background
# 3199986     53  UDP  .A....   0  72   1     76  background
# 3199987     53  UDP  .A....   0  72   1     76  background
# 3199988     53  UDP  .A....   0  72   1     76  background
# 3199989     53  UDP  .A....   0  72   1     76  background
# 3199990     53  UDP  .A....   0  72   1     76  background
# 3199991     53  UDP  .A....   0  72   1     76  background
# 3199992     53  UDP  .A....   0  72   1     76  background
# 3199993     53  UDP  .A....   0  72   1     76  background
# 3199994     53  UDP  .A....   0  72   1     76  background
# 3199995    443  TCP  ....S.   0   2   1     52  background
# 3199996    443  TCP  ....S.   0   2   1     52  background
# 3199997     80  TCP  .AP...   0   2   1    706  background
# 3199998     80  TCP  .A.R..   0   0   1     40  background
# 3199999     80  TCP  .A.R..   0   0   1     40  background
#
# [200000 rows x 13 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e2137d16c39f> in <module>
#       1 df_not_chunk = pd.read_csv(path, header=None, chunksize=200000)
# ----> 2 for df in df_not_chunk:
#       3     print(df)
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in __next__(self)
#    1113     def __next__(self):
#    1114         try:
# -> 1115             return self.get_chunk()
#    1116         except StopIteration:
#    1117             self.close()
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#    1171                 raise StopIteration
#    1172             size = min(size, self.nrows - self._currow)
# -> 1173         return self.read(nrows=size)
#    1174
#    1175
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1993     def read(self, nrows=None):
#    1994         try:
# -> 1995             data = self._reader.read(nrows)
#    1996         except StopIteration:
#    1997             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     570
#     571
# --> 572 def is_categorical_dtype(arr_or_dtype):
#     573     """
#     574     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %%
print("Read {} rows.".format(len(df)))
# df = df.sample(frac=0.1, replace=False) # Uncomment this line to sample only 10% of the dataset
df.dropna(inplace=True,axis=1) # For now, just drop NA's (rows with missing values)

# The CSV file has no column heads, so add them
df.columns = [
    'time',
    'duration',
    'sip',
    'dip',
    'source_port',
    'dest_port',
    'protocol',
    'flags',
    'forward_status',
    'type_service',
    'pack_exch',
    'bytes',
    'attack_tag'
]
# Out:
# Read 200000 rows.

# %%
#print(df[0:3])

ENCODING = 'utf-8'

def expand_categories(values):
    result = []
    s = values.value_counts()
    t = float(len(values))
    for v in s.index:
        result.append("{}:{}%".format(v,round(100*(s[v]/t),2)))
    return "[{}]".format(",".join(result))
        
def analyze(filename):
    print()
    print("Analyzing: {}".format(filename))
    df = pd.read_csv(filename,encoding=ENCODING)
    cols = df.columns.values
    total = float(len(df))

    print("{} rows".format(int(total)))
    for col in cols:
        uniques = df[col].unique()
        unique_count = len(uniques)
        if unique_count>100:
            print("** {}:{} ({}%)".format(col,unique_count,int(((unique_count)/total)*100)))
        else:
            print("** {}:{}".format(col,expand_categories(df[col])))
            expand_categories(df[col])

#analyze(path)

######RESULT######
#####################################################
# 9999998 rows
# ** 2016-03-18 10:52:40:10719 (0%)
# ** 0.000:35412 (0%)
# ** 127.204.60.89:892565 (8%)
# ** 42.219.153.89:4098 (0%)
# ** 123:65536 (0%)
# ** 425:64147 (0%)
# ** UDP:[TCP:62.27%,UDP:36.56%,ICMP:1.05%,GRE:0.06%,ESP:0.05%,IPIP:0.01%,IPv6:0.0%]
# ** .A....:[.A....:40.27%,.AP.SF:26.33%,.AP.S.:7.04%,.AP...:6.6%,.APRSF:4.37%,.A...F:4.04%,....S.:2.5%,.APRS.:2.18%,.AP..F:1.85%,.A..SF:1.66%,.A.R..:0.87%,.A..S.:0.64%,.A.R.F:0.45%,...R..:0.45%,.APR..:0.44%,.APR.F:0.18%,.A.RS.:0.06%,...RS.:0.04%,.A.RSF:0.02%,......:0.01%,UAP..F:0.0%,UAP.S.:0.0%,..P.S.:0.0%]
# ** 0:[0:100.0%]
# ** 0.1:[0:66.46%,40:20.13%,72:8.62%,8:1.48%,64:1.3%,42:0.76%,24:0.4%,2:0.39%,26:0.17%,104:0.07%,75:0.05%,16:0.04%,20:0.02%,192:0.02%,74:0.02%,96:0.01%,28:0.01%,4:0.01%,224:0.01%,43:0.01%,6:0.0%,18:0.0%,12:0.0%,184:0.0%,32:0.0%,73:0.0%,10:0.0%,152:0.0%,23:0.0%,88:0.0%,13:0.0%,3:0.0%,48:0.0%,66:0.0%,160:0.0%,56:0.0%,194:0.0%,80:0.0%,15:0.0%,25:0.0%,9:0.0%,1:0.0%,17:0.0%,14:0.0%,92:0.0%,200:0.0%,19:0.0%,21:0.0%,22:0.0%,30:0.0%,41:0.0%,5:0.0%,240:0.0%,11:0.0%,27:0.0%,68:0.0%,7:0.0%,136:0.0%,29:0.0%]
# ** 1:8245 (0%)
# ** 76:116716 (1%)
# ** background:[background:99.7%,blacklist:0.28%,anomaly-spam:0.02%]
########################################################

# Encode text values to dummy variables(i.e. [1,0,0],[0,1,0],[0,0,1] for red,green,blue)
def encode_text_dummy(df, name):
    dummies = pd.get_dummies(df[name])
    for x in dummies.columns:
        dummy_name = f"{name}-{x}"
        df[dummy_name] = dummies[x]
    df.drop(name, axis=1, inplace=True)

#Clean 'date' column and convert to Int type
def clean_date(s):
    s = ''.join([i for i in s if i not in frozenset(string.punctuation)])
    s_removed = s.replace(" ", "")
    s_int = int(s_removed)
    return s_int

########## CLEAN IP #######################
def clean_ip(s):
    s = ''.join([i for i in s if i not in frozenset(string.punctuation)])
    s_int = int(s)
    return s_int

# Encode a numeric column as zscores
def encode_numeric_zscore(df, name, mean=None, sd=None):
    if mean is None:
        mean = df[name].mean()

    if sd is None:
        sd = df[name].std()

    df[name] = (df[name] - mean) / sd


# Encode text values to indexes(i.e. [1],[2],[3] for red,green,blue).
def encode_text_index(df, name):
    le = preprocessing.LabelEncoder()
    df[name] = le.fit_transform(df[name])
    return le.classes_

#LAS QUE YA SON NUMEROS --> no los normalizo de momento
# encode_numeric_zscore(df, 'duration')
# encode_numeric_zscore(df, 'source_port')
# encode_numeric_zscore(df, 'dest_port')
# encode_numeric_zscore(df, 'forward_status')
# encode_numeric_zscore(df, 'type_service')
# encode_numeric_zscore(df, 'pack_exch')
# encode_numeric_zscore(df, 'bytes')


encode_text_dummy(df, 'protocol')
encode_text_dummy(df, 'flags')
#encode_text_dummy(df, 'attack_tag')

outcomes = encode_text_index(df, 'attack_tag')
num_classes = len(outcomes)

#Me crea una columna AL FINAL nueva con los valores transformdos asi 20160318105240
df['time'] = df['time'].apply(clean_date)

df['sip'] = df['sip'].apply(clean_ip)
df['dip'] = df['dip'].apply(clean_ip)

encode_numeric_zscore(df, 'time')
encode_numeric_zscore(df, 'sip')
encode_numeric_zscore(df, 'dip')


print(df.shape)
print(df[0:3])

# Convert a Pandas dataframe to the x,y inputs that TensorFlow needs
def to_xy(df, target):
    result = []
    for x in df.columns:
        if x != target:
            result.append(x)
    # find out the type of the target column.  Is it really this hard? :(
    target_type = df[target].dtypes
    target_type = target_type[0] if hasattr(
        target_type, '__iter__') else target_type
    # Encode to int for classification, float otherwise. TensorFlow likes 32 bits.
    if target_type in (np.int64, np.int32):
        # Classification
        dummies = pd.get_dummies(df[target])
        return df[result].values.astype(np.float32), dummies.values.astype(np.float32)
    # Regression
    return df[result].values.astype(np.float32), df[[target]].values.astype(np.float32)


##################################################
# Break into X (predictors) & y (prediction)
x, y = to_xy(df,'attack_tag')
#################################################



# Create a test/train split.  25% test
# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.25, random_state=42)

# Create neural net
model = Sequential()
model.add(Dense(10, input_dim=x.shape[1], kernel_initializer='normal', activation='relu'))
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='normal', activation='relu'))
model.add(Dense(10, input_dim=x.shape[1], kernel_initializer='normal', activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))
model.add(Dense(y.shape[1],activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')
model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor],verbose=2,epochs=1000)


# Measure accuracy
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
y_eval = np.argmax(y_test,axis=1)
score = metrics.accuracy_score(y_eval, pred)
print("Validation score: {}".format(score))
# Out:
# (200000, 38)
#              time  duration       sip      dip  source_port  dest_port  \
# 3000000 -1.464808     0.076 -0.204843  0.35219         8291      54194
# 3000001 -1.464808     0.076 -0.577410  0.35219        51342      41005
# 3000002 -1.464808     0.076  0.436119 -0.14530           80      54697
#
#          forward_status  type_service  pack_exch  bytes  ...  flags-.A.RS.  \
# 3000000               0             0          2     92  ...             0
# 3000001               0             0          5    232  ...             0
# 3000002               0             0          4    844  ...             0
#
#          flags-.A.RSF  flags-.AP...  flags-.AP..F  flags-.AP.S.  flags-.AP.SF  \
# 3000000             0             0             0             0             0
# 3000001             0             0             0             0             1
# 3000002             0             0             0             0             1
#
#          flags-.APR..  flags-.APR.F  flags-.APRS.  flags-.APRSF
# 3000000             0             0             0             0
# 3000001             0             0             0             0
# 3000002             0             0             0             0
#
# [3 rows x 38 columns]
# Train on 150000 samples, validate on 50000 samples
# Epoch 1/1000
#  - 7s - loss: 0.0895 - acc: 0.9944 - val_loss: 0.0894 - val_acc: 0.9944
# Epoch 2/1000
#  - 6s - loss: 0.0878 - acc: 0.9945 - val_loss: 0.0705 - val_acc: 0.9944
# Epoch 3/1000
#  - 6s - loss: 0.0702 - acc: 0.9944 - val_loss: 0.0874 - val_acc: 0.9944
# Epoch 4/1000
#  - 6s - loss: 0.0597 - acc: 0.9945 - val_loss: 0.0461 - val_acc: 0.9944
# Epoch 5/1000
#  - 6s - loss: 0.0431 - acc: 0.9944 - val_loss: 0.0345 - val_acc: 0.9944
# Epoch 6/1000
#  - 6s - loss: 0.0351 - acc: 0.9944 - val_loss: 0.0352 - val_acc: 0.9944
# Epoch 7/1000
#  - 7s - loss: 0.0347 - acc: 0.9944 - val_loss: 0.0354 - val_acc: 0.9944
# Epoch 8/1000
#  - 7s - loss: 0.0347 - acc: 0.9944 - val_loss: 0.0343 - val_acc: 0.9944
# Epoch 9/1000
#  - 7s - loss: 0.0413 - acc: 0.9943 - val_loss: 0.0338 - val_acc: 0.9944
# Epoch 10/1000
#  - 7s - loss: 0.0348 - acc: 0.9944 - val_loss: 0.0340 - val_acc: 0.9943
# Epoch 00010: early stopping
# Validation score: 0.99432

# %%
df_not_chunk = pd.read_csv(path, header=None, chunksize=200000)

##########################CHUNKSIZE###################################################
chunk_list = [] #append echa chunk df here

#Each chunk is in a df format
#for df in df_not_chunk:
#    print(df)

#########################################################################################


print("Read {} rows.".format(len(df)))
# df = df.sample(frac=0.1, replace=False) # Uncomment this line to sample only 10% of the dataset
df.dropna(inplace=True,axis=1) # For now, just drop NA's (rows with missing values)

# The CSV file has no column heads, so add them
df.columns = [
    'time',
    'duration',
    'sip',
    'dip',
    'source_port',
    'dest_port',
    'protocol',
    'flags',
    'forward_status',
    'type_service',
    'pack_exch',
    'bytes',
    'attack_tag'
]

#print(df[0:3])

ENCODING = 'utf-8'

def expand_categories(values):
    result = []
    s = values.value_counts()
    t = float(len(values))
    for v in s.index:
        result.append("{}:{}%".format(v,round(100*(s[v]/t),2)))
    return "[{}]".format(",".join(result))
        
def analyze(filename):
    print()
    print("Analyzing: {}".format(filename))
    df = pd.read_csv(filename,encoding=ENCODING)
    cols = df.columns.values
    total = float(len(df))

    print("{} rows".format(int(total)))
    for col in cols:
        uniques = df[col].unique()
        unique_count = len(uniques)
        if unique_count>100:
            print("** {}:{} ({}%)".format(col,unique_count,int(((unique_count)/total)*100)))
        else:
            print("** {}:{}".format(col,expand_categories(df[col])))
            expand_categories(df[col])

#analyze(path)

######RESULT######
#####################################################
# 9999998 rows
# ** 2016-03-18 10:52:40:10719 (0%)
# ** 0.000:35412 (0%)
# ** 127.204.60.89:892565 (8%)
# ** 42.219.153.89:4098 (0%)
# ** 123:65536 (0%)
# ** 425:64147 (0%)
# ** UDP:[TCP:62.27%,UDP:36.56%,ICMP:1.05%,GRE:0.06%,ESP:0.05%,IPIP:0.01%,IPv6:0.0%]
# ** .A....:[.A....:40.27%,.AP.SF:26.33%,.AP.S.:7.04%,.AP...:6.6%,.APRSF:4.37%,.A...F:4.04%,....S.:2.5%,.APRS.:2.18%,.AP..F:1.85%,.A..SF:1.66%,.A.R..:0.87%,.A..S.:0.64%,.A.R.F:0.45%,...R..:0.45%,.APR..:0.44%,.APR.F:0.18%,.A.RS.:0.06%,...RS.:0.04%,.A.RSF:0.02%,......:0.01%,UAP..F:0.0%,UAP.S.:0.0%,..P.S.:0.0%]
# ** 0:[0:100.0%]
# ** 0.1:[0:66.46%,40:20.13%,72:8.62%,8:1.48%,64:1.3%,42:0.76%,24:0.4%,2:0.39%,26:0.17%,104:0.07%,75:0.05%,16:0.04%,20:0.02%,192:0.02%,74:0.02%,96:0.01%,28:0.01%,4:0.01%,224:0.01%,43:0.01%,6:0.0%,18:0.0%,12:0.0%,184:0.0%,32:0.0%,73:0.0%,10:0.0%,152:0.0%,23:0.0%,88:0.0%,13:0.0%,3:0.0%,48:0.0%,66:0.0%,160:0.0%,56:0.0%,194:0.0%,80:0.0%,15:0.0%,25:0.0%,9:0.0%,1:0.0%,17:0.0%,14:0.0%,92:0.0%,200:0.0%,19:0.0%,21:0.0%,22:0.0%,30:0.0%,41:0.0%,5:0.0%,240:0.0%,11:0.0%,27:0.0%,68:0.0%,7:0.0%,136:0.0%,29:0.0%]
# ** 1:8245 (0%)
# ** 76:116716 (1%)
# ** background:[background:99.7%,blacklist:0.28%,anomaly-spam:0.02%]
########################################################

# Encode text values to dummy variables(i.e. [1,0,0],[0,1,0],[0,0,1] for red,green,blue)
def encode_text_dummy(df, name):
    dummies = pd.get_dummies(df[name])
    for x in dummies.columns:
        dummy_name = f"{name}-{x}"
        df[dummy_name] = dummies[x]
    df.drop(name, axis=1, inplace=True)

#Clean 'date' column and convert to Int type
def clean_date(s):
    s = ''.join([i for i in s if i not in frozenset(string.punctuation)])
    s_removed = s.replace(" ", "")
    s_int = int(s_removed)
    return s_int

########## CLEAN IP #######################
def clean_ip(s):
    s = ''.join([i for i in s if i not in frozenset(string.punctuation)])
    s_int = int(s)
    return s_int

# Encode a numeric column as zscores
def encode_numeric_zscore(df, name, mean=None, sd=None):
    if mean is None:
        mean = df[name].mean()

    if sd is None:
        sd = df[name].std()

    df[name] = (df[name] - mean) / sd


# Encode text values to indexes(i.e. [1],[2],[3] for red,green,blue).
def encode_text_index(df, name):
    le = preprocessing.LabelEncoder()
    df[name] = le.fit_transform(df[name])
    return le.classes_

#LAS QUE YA SON NUMEROS --> no los normalizo de momento
# encode_numeric_zscore(df, 'duration')
# encode_numeric_zscore(df, 'source_port')
# encode_numeric_zscore(df, 'dest_port')
# encode_numeric_zscore(df, 'forward_status')
# encode_numeric_zscore(df, 'type_service')
# encode_numeric_zscore(df, 'pack_exch')
# encode_numeric_zscore(df, 'bytes')

df.info()
encode_text_dummy(df, 'protocol')
encode_text_dummy(df, 'flags')
#encode_text_dummy(df, 'attack_tag')


outcomes = encode_text_index(df, 'attack_tag')
num_classes = len(outcomes)

#Me crea una columna AL FINAL nueva con los valores transformdos asi 20160318105240
df['time'] = df['time'].apply(clean_date)

df['sip'] = df['sip'].apply(clean_ip)
df['dip'] = df['dip'].apply(clean_ip)

encode_numeric_zscore(df, 'time')
encode_numeric_zscore(df, 'sip')
encode_numeric_zscore(df, 'dip')

df.info()

print(df.shape)
print(df[0:3])

# Convert a Pandas dataframe to the x,y inputs that TensorFlow needs
def to_xy(df, target):
    result = []
    for x in df.columns:
        if x != target:
            result.append(x)
    # find out the type of the target column.  Is it really this hard? :(
    target_type = df[target].dtypes
    target_type = target_type[0] if hasattr(
        target_type, '__iter__') else target_type
    # Encode to int for classification, float otherwise. TensorFlow likes 32 bits.
    if target_type in (np.int64, np.int32):
        # Classification
        dummies = pd.get_dummies(df[target])
        return df[result].values.astype(np.float32), dummies.values.astype(np.float32)
    # Regression
    return df[result].values.astype(np.float32), df[[target]].values.astype(np.float32)


##################################################
# Break into X (predictors) & y (prediction)
x, y = to_xy(df,'attack_tag')
#################################################



# Create a test/train split.  25% test
# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.25, random_state=42)

# Create neural net
model = Sequential()
model.add(Dense(10, input_dim=x.shape[1], kernel_initializer='normal', activation='relu'))
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='normal', activation='relu'))
model.add(Dense(10, input_dim=x.shape[1], kernel_initializer='normal', activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))
model.add(Dense(y.shape[1],activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')
model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor],verbose=2,epochs=1000)


# Measure accuracy
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
y_eval = np.argmax(y_test,axis=1)
score = metrics.accuracy_score(y_eval, pred)
print("Validation score: {}".format(score))
# Out:
# Read 200000 rows.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-548f0219e598> in <module>
#      29     'pack_exch',
#      30     'bytes',
# ---> 31     'attack_tag'
#      32 ]
#      33
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5078         try:
#    5079             object.__getattribute__(self, name)
# -> 5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#    5082             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     636
#     637     def _set_axis(self, axis, labels):
# --> 638         self._data.set_axis(axis, labels)
#     639         self._clear_item_cache()
#     640
#
# /miniconda3/envs/tf_jupyter/lib/python3.6/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     153             raise ValueError(
#     154                 'Length mismatch: Expected axis has {old} elements, new '
# --> 155                 'values have {new} elements'.format(old=old_len, new=new_len))
#     156
#     157         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 38 elements, new values have 13 elements

# %%
import pandas as pd
import io
import requests
import numpy as np
import os

import tensorflow.contrib.learn as skflow
import string

from scipy.stats import zscore

from sklearn.model_selection import train_test_split
from sklearn import metrics
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.callbacks import EarlyStopping
from sklearn import preprocessing

#####################################################
#os.system('python 22_05_Transform_columns.py')
#No puedo ponerlo asi por que entonces dice que no esta definido df
#Seguro que hay alguna manera
#####################################################

path = "../july_reduced copia.csv"
# This file is a CSV, just no CSV extension or headers
df = pd.read_csv(path, header=None, chunksize=200000)
# Out:
# Using TensorFlow backend.

# %%
##########################CHUNKSIZE###################################################
chunk_list = [] #append echa chunk df here

#Each chunk is in a df format
for df in df_not_chunk:
    print(df)

#########################################################################################


print("Read {} rows.".format(len(df)))
# df = df.sample(frac=0.1, replace=False) # Uncomment this line to sample only 10% of the dataset
df.dropna(inplace=True,axis=1) # For now, just drop NA's (rows with missing values)


# The CSV file has no column heads, so add them
df.columns = [
    'time',
    'duration',
    'sip',
    'dip',
    'source_port',
    'dest_port',
    'protocol',
    'flags',
    'forward_status',
    'type_service',
    'pack_exch',
    'bytes',
    'attack_tag'
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7c70beee4a39> in <module>
#       3
#       4 #Each chunk is in a df format
# ----> 5 for df in df_not_chunk:
#       6     print(df)
#       7
#
# NameError: name 'df_not_chunk' is not defined

# %%
print("Read {} rows.".format(len(df)))
# df = df.sample(frac=0.1, replace=False) # Uncomment this line to sample only 10% of the dataset
df.dropna(inplace=True,axis=1) # For now, just drop NA's (rows with missing values)


# The CSV file has no column heads, so add them
df.columns = [
    'time',
    'duration',
    'sip',
    'dip',
    'source_port',
    'dest_port',
    'protocol',
    'flags',
    'forward_status',
    'type_service',
    'pack_exch',
    'bytes',
    'attack_tag'
]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-a4550b14b064> in <module>
# ----> 1 print("Read {} rows.".format(len(df)))
#       2 # df = df.sample(frac=0.1, replace=False) # Uncomment this line to sample only 10% of the dataset
#       3 df.dropna(inplace=True,axis=1) # For now, just drop NA's (rows with missing values)
#       4
#       5
#
# TypeError: object of type 'TextFileReader' has no len()

# %%
print(df[0:3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-66714e9c3a74> in <module>
# ----> 1 print(df[0:3])
#
# TypeError: 'TextFileReader' object is not subscriptable

# %%
import pandas as pd
import io
import requests
import numpy as np
import os

import tensorflow.contrib.learn as skflow
import string

from scipy.stats import zscore

from sklearn.model_selection import train_test_split
from sklearn import metrics
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.callbacks import EarlyStopping
from sklearn import preprocessing

#####################################################
#os.system('python 22_05_Transform_columns.py')
#No puedo ponerlo asi por que entonces dice que no esta definido df
#Seguro que hay alguna manera
#####################################################

path = "../july_reduced copia.csv"
# This file is a CSV, just no CSV extension or headers
df_not_chunk = pd.read_csv(path, header=None, chunksize=200000)

##########################CHUNKSIZE###################################################
chunk_list = [] #append echa chunk df here

#Each chunk is in a df format
for df in df_not_chunk:
    #print(df[0:3])

#########################################################################################


#print("Read {} rows.".format(len(df)))
# df = df.sample(frac=0.1, replace=False) # Uncomment this line to sample only 10% of the dataset
df.dropna(inplace=True,axis=1) # For now, just drop NA's (rows with missing values)


# The CSV file has no column heads, so add them
df.columns = [
    'time',
    'duration',
    'sip',
    'dip',
    'source_port',
    'dest_port',
    'protocol',
    'flags',
    'forward_status',
    'type_service',
    'pack_exch',
    'bytes',
    'attack_tag'
]

print(df[0:3])

ENCODING = 'utf-8'

def expand_categories(values):
    result = []
    s = values.value_counts()
    t = float(len(values))
    for v in s.index:
        result.append("{}:{}%".format(v,round(100*(s[v]/t),2)))
    return "[{}]".format(",".join(result))
        
def analyze(filename):
    print()
    print("Analyzing: {}".format(filename))
    df = pd.read_csv(filename,encoding=ENCODING)
    cols = df.columns.values
    total = float(len(df))

    print("{} rows".format(int(total)))
    for col in cols:
        uniques = df[col].unique()
        unique_count = len(uniques)
        if unique_count>100:
            print("** {}:{} ({}%)".format(col,unique_count,int(((unique_count)/total)*100)))
        else:
            print("** {}:{}".format(col,expand_categories(df[col])))
            expand_categories(df[col])

#analyze(path)

######RESULT######
#####################################################
# 9999998 rows
# ** 2016-03-18 10:52:40:10719 (0%)
# ** 0.000:35412 (0%)
# ** 127.204.60.89:892565 (8%)
# ** 42.219.153.89:4098 (0%)
# ** 123:65536 (0%)
# ** 425:64147 (0%)
# ** UDP:[TCP:62.27%,UDP:36.56%,ICMP:1.05%,GRE:0.06%,ESP:0.05%,IPIP:0.01%,IPv6:0.0%]
# ** .A....:[.A....:40.27%,.AP.SF:26.33%,.AP.S.:7.04%,.AP...:6.6%,.APRSF:4.37%,.A...F:4.04%,....S.:2.5%,.APRS.:2.18%,.AP..F:1.85%,.A..SF:1.66%,.A.R..:0.87%,.A..S.:0.64%,.A.R.F:0.45%,...R..:0.45%,.APR..:0.44%,.APR.F:0.18%,.A.RS.:0.06%,...RS.:0.04%,.A.RSF:0.02%,......:0.01%,UAP..F:0.0%,UAP.S.:0.0%,..P.S.:0.0%]
# ** 0:[0:100.0%]
# ** 0.1:[0:66.46%,40:20.13%,72:8.62%,8:1.48%,64:1.3%,42:0.76%,24:0.4%,2:0.39%,26:0.17%,104:0.07%,75:0.05%,16:0.04%,20:0.02%,192:0.02%,74:0.02%,96:0.01%,28:0.01%,4:0.01%,224:0.01%,43:0.01%,6:0.0%,18:0.0%,12:0.0%,184:0.0%,32:0.0%,73:0.0%,10:0.0%,152:0.0%,23:0.0%,88:0.0%,13:0.0%,3:0.0%,48:0.0%,66:0.0%,160:0.0%,56:0.0%,194:0.0%,80:0.0%,15:0.0%,25:0.0%,9:0.0%,1:0.0%,17:0.0%,14:0.0%,92:0.0%,200:0.0%,19:0.0%,21:0.0%,22:0.0%,30:0.0%,41:0.0%,5:0.0%,240:0.0%,11:0.0%,27:0.0%,68:0.0%,7:0.0%,136:0.0%,29:0.0%]
# ** 1:8245 (0%)
# ** 76:116716 (1%)
# ** background:[background:99.7%,blacklist:0.28%,anomaly-spam:0.02%]
########################################################

# Encode text values to dummy variables(i.e. [1,0,0],[0,1,0],[0,0,1] for red,green,blue)
def encode_text_dummy(df, name):
    dummies = pd.get_dummies(df[name])
    for x in dummies.columns:
        dummy_name = f"{name}-{x}"
        df[dummy_name] = dummies[x]
    df.drop(name, axis=1, inplace=True)

#Clean 'date' column and convert to Int type
def clean_date(s):
    s = ''.join([i for i in s if i not in frozenset(string.punctuation)])
    s_removed = s.replace(" ", "")
    s_int = int(s_removed)
    return s_int

########## CLEAN IP #######################
def clean_ip(s):
    s = ''.join([i for i in s if i not in frozenset(string.punctuation)])
    s_int = int(s)
    return s_int

# Encode a numeric column as zscores
def encode_numeric_zscore(df, name, mean=None, sd=None):
    if mean is None:
        mean = df[name].mean()

    if sd is None:
        sd = df[name].std()

    df[name] = (df[name] - mean) / sd


# Encode text values to indexes(i.e. [1],[2],[3] for red,green,blue).
def encode_text_index(df, name):
    le = preprocessing.LabelEncoder()
    df[name] = le.fit_transform(df[name])
    return le.classes_

#LAS QUE YA SON NUMEROS --> no los normalizo de momento
# encode_numeric_zscore(df, 'duration')
# encode_numeric_zscore(df, 'source_port')
# encode_numeric_zscore(df, 'dest_port')
# encode_numeric_zscore(df, 'forward_status')
# encode_numeric_zscore(df, 'type_service')
# encode_numeric_zscore(df, 'pack_exch')
# encode_numeric_zscore(df, 'bytes')

df.drop('time', 1, inplace=True)
print(df[0:3])

encode_text_dummy(df, 'protocol')
encode_text_dummy(df, 'flags')
#encode_text_dummy(df, 'attack_tag')

outcomes = encode_text_index(df, 'attack_tag')
num_classes = len(outcomes)

#Me crea una columna AL FINAL nueva con los valores transformdos asi 20160318105240
#df['time'] = df['time'].apply(clean_date)

df['sip'] = df['sip'].apply(clean_ip)
df['dip'] = df['dip'].apply(clean_ip)

encode_numeric_zscore(df, 'sip')
encode_numeric_zscore(df, 'dip')


print(df.shape)
#print(df[0:3])

# Convert a Pandas dataframe to the x,y inputs that TensorFlow needs
def to_xy(df, target):
    result = []
    for x in df.columns:
        if x != target:
            result.append(x)
    # find out the type of the target column.  Is it really this hard? :(
    target_type = df[target].dtypes
    target_type = target_type[0] if hasattr(
        target_type, '__iter__') else target_type
    # Encode to int for classification, float otherwise. TensorFlow likes 32 bits.
    if target_type in (np.int64, np.int32):
        # Classification
        dummies = pd.get_dummies(df[target])
        return df[result].values.astype(np.float32), dummies.values.astype(np.float32)
    # Regression
    return df[result].values.astype(np.float32), df[[target]].values.astype(np.float32)


##################################################
# Break into X (predictors) & y (prediction)
x, y = to_xy(df,'attack_tag')
#################################################



# Create a test/train split.  25% test
# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.25, random_state=42)

# Create neural net
model = Sequential()
model.add(Dense(10, input_dim=x.shape[1], kernel_initializer='normal', activation='relu'))
model.add(Dense(50, input_dim=x.shape[1], kernel_initializer='normal', activation='relu'))
model.add(Dense(10, input_dim=x.shape[1], kernel_initializer='normal', activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))
model.add(Dense(y.shape[1],activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')
model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor],verbose=2,epochs=1000)


# Measure accuracy
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
y_eval = np.argmax(y_test,axis=1)
score = metrics.accuracy_score(y_eval, pred)
print("Validation score: {}".format(score))
# Out:
#   File "<ipython-input-8-f07993e8b723>", line 41
#     df.dropna(inplace=True,axis=1) # For now, just drop NA's (rows with missing values)
#      ^
# IndentationError: expected an indented block
